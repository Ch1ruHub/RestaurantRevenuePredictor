# %% [markdown]
# # Restaurant Monthly Revenue: Linear Regression
#
# This notebook executes the reproducible workflow in `model_training.py`. It checks data quality, caps invalid customer ratings, removes the identifier, runs the assumption diagnostics, fits an 80/20 train-test linear-regression pipeline, saves `model.pkl`, and writes the supporting tables and figures.

# %%
# Run this cell from the folder containing restaurant.csv and model_training.py
# %run model_training.py

# %% [markdown]
# ## How to interpret the outputs
#
# `data_quality_report.csv` documents missing, duplicate, and range checks; `data_corrections.json` records the rating cap. `vif_report.csv` checks multicollinearity. `model_metrics.json` records test metrics, Durbin-Watson, and influence counts. The `figures` folder contains residual-vs-fitted, Q-Q, Cook's distance, and linearity plots. Influential but valid generated rows are retained and explicitly reported rather than silently removed.
